# %% [markdown]
# # Solicitudes a la web

# %%
import requests
response = requests.get('https://www.platzi.com')

# %%
response.encoding = 'utf-8'

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.text)
# Out:
#     <!doctype html>
#       <html lang=es-CO>
#         <head>
#           <meta charset="UTF-8">
#
#           <meta name="viewport" content="width=device-width, initial-scale=1" />
#           <title>🚀Platzi: ‎Cursos Online Profesionales de Tecnología</title>
#           <link rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/home.ad56aafe38d2248aff48.css" type="text/css" />
#           <link rel="shortcut icon" href="//static.platzi.com/media/favicons/platzi_favicon.png" />
#           <link rel="icon" sizes="192x192" href="//static.platzi.com/media/favicons/platzi_favicon.png">
#           <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="" />
#
#     <meta name="description" content="Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!">
#     <meta name = "theme-color" content = "#15210B" />
#
# ...

# %% [markdown]
# # Extracciòn de informaciòn del HTML

# %%
import bs4
soup = bs4.BeautifulSoup(response.text, 'html.parser',)

print(soup.title.text)
# Out:
# ðPlatzi: âCursos Online Profesionales de TecnologÃ­a

# %%
print(soup.select('meta[name=description]')[0]['content'])
# Out:
# Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!

# %%
courses_link = soup.select('.RecentCourses-item a')

# %%
for i in courses_link[0]:
    print(i)
    print('__')
# Out:
# <div class="RecentCourses-badge"><figure><img alt="Meditaciones para Seguir Aprendiendo" loading="lazy" src="https://static.platzi.com/media/achievements/badge-taller-practico-meditacion-b7654b5f-32d8-4f69-ac82-712fa8a1f759.png"/></figure></div>
# __
# <div class="RecentCourses-content"><h3>Meditaciones para Seguir Aprendiendo</h3><div class="RecentCourses-arrow"></div></div>
# __
# <a href="/cursos/meditacion"></a>
# __

# %%
courses_link[0].a['href']
# Out:
# '/cursos/meditacion'

# %%
courses = [course.a['href'] for course in courses_link]

# %%
for i in courses:
    print(i)
# Out:
# /cursos/meditacion
# /cursos/devtools
# /cursos/keras-neural-networks
# /cursos/guion-series
# /cursos/arte-escenarios
# /cursos/avanzado-vue
# /cursos/pic
# /cursos/kotlin-android
# /cursos/data-studio
# /cursos/intro-laravel
# /cursos/camino-emprendedor
# /cursos/habilidades-blandas
# /cursos/travis
# /cursos/programacion-golang
# /cursos/patrones-android

# %% [markdown]
# # Extracciòn de informaciòn a periodico EL UNIVERSAL 07/04/2020

# %%
response = requests.get('https://www.eluniversal.com.mx/')

# %%
soup = bs4.BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.title.text)
# Out:
# El Universal | El periódico de México líder en noticias y clasificados

# %%
urls_noticias = soup.select('.field-content a')

# %%
noticias = [noticia['href'] for noticia in urls_noticias]

# %%
print(soup.select('.field-content'))
# Out:
# [<h2 class="field-content"><a href="/es-noticia/nacion/sociedad/coronavirus-en-mexico">Coronavirus en México</a></h2>, <h2 class="field-content"><a href="/es-noticia/nacion/sociedad/cuarentena">Cuarentena</a></h2>, <h2 class="field-content"><a href="/es-noticia/mundo/coronavirus">Coronavirus</a></h2>, <div class="field-content"><a href="https://www.eluniversal.com.mx/opinion/editorial-el-universal/ayuda-y-quedateencasa"><img alt="Quédate en casa" height="100" src="https://www.eluniversal.com.mx/sites/default/files/styles/exclude-cintillo/public/cintillo_superior/2020/03/30/quedate_en_casa.jpg?itok=ynO-mHjf" title="Quédate en casa" width="1023"/></a></div>, <span class="field-content"><div class="view view-especiales-nodo view-id-especiales_nodo view-display-id-panel_pane_1 view-dom-id-e4f43181e6d5bda4afaaf313dcecba55">
# <div class="view-content">
# <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
# ...

# %% [markdown]
# ## Analisis de EL PAIS para el web scrapper

# %%
response = requests.get('https://www.elsoldecordoba.com.mx/local/cuarentena-puede-agravar-problemas-emocionales-en-la-ciudadania-veracruz-cuarentena-estres-psicologa-5072722.html')
soup = bs4.BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.select('.title')[0].text)
# Out:
# Cuarentena puede agravar problemas emocionales en la ciudadanía

# %%
print(soup.select('.content-body p')[0].text)
# Out:
# Córdoba, Ver.- Estrés, ansiedad y depresión son algunos de los padecimientos que pueden llegar a presentar los ciudadanos al estar encerrados, sin embargo es por contingencia; aquellos pacientes que ya presentaban estos aspectos pueden llegar a empeorar, explicó la psicóloga Raquel González Córdova.

# %%
response = requests.get('https://www.unionguanajuato.mx/articulo/2020/03/19/cultura/coronavirus-cuando-empieza-y-cuanto-dura-la-cuarentena-en-mexico')
soup = bs4.BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
huatusco = pd.read_csv('./web_scrapper/huatusco_2020_04_d_articles.csv', encoding = 'ISO-8859-1')

# %%
huatusco.head()
# Out:
#                                                 body  \
# 0  \r\nCiclistas de diferentes municipios hiciero...
# 1  \r\nLa noticia de su extinción la dio a conoce...
# 2  \r\nAsí lo dio a conocer el Director del DIF m...
# 3  \r\nEsto a partir del sorteo que realizó el Co...
# 4  \r\nLos hechos ocurrieron minutos antes de las...
#
#                                                title  \
# 0  \r\n\t\t\t\t\tEn Huatusco, 350 ciclistas parti...
# 1  \r\n\t\t\t\t\tEsta es la primera especie que e...
# 2  \r\n\t\t\t\t\tEntregan proyectos productivos e...
# 3  \r\n\t\t\t\t\t Ciudadanas y ciudadanos nacidos...
# 4  \r\n\t\t\t\t\tLevantan a El Cocho Villafuer...
#
#                                                  url
# 0  http://huatusconoticias.com/portal//portal/ind...
# 1  http://huatusconoticias.com/portal//portal/ind...
# 2  http://huatusconoticias.com/portal//portal/ind...
# 3  http://huatusconoticias.com/portal//portal/ind...
# 4  http://huatusconoticias.com/portal//portal/ind...

# %%
#dictonary like

huatusco['title']
# Out:
# 0     \r\n\t\t\t\t\tEn Huatusco, 350 ciclistas parti...
# 1     \r\n\t\t\t\t\tEsta es la primera especie que e...
# 2     \r\n\t\t\t\t\tEntregan proyectos productivos e...
# 3     \r\n\t\t\t\t\t Ciudadanas y ciudadanos nacidos...
# 4     \r\n\t\t\t\t\tLevantan a El Cocho Villafuer...
# 5     \r\n\t\t\t\t\t Asaltan y lesionan sujetos con ...
# 6     \r\n\t\t\t\t\tFuera Lety, el pueblo no te qui...
# 7     \r\n\t\t\t\t\t Comando armado levanta a ocho...
# 8     \r\n\t\t\t\t\tDisfrutan cordobeses de 1ra. Rod...
# 9     \r\n\t\t\t\t\tCae taxista de Huatusco con drog...
# 10    \r\n\t\t\t\t\tBajarán las multas de tránsito...
# 11    \r\n\t\t\t\t\t*Baristas fortalecen al café ver...
# 12    \r\n\t\t\t\t\tSe dispara deforestación en el P...
# 13    \r\n\t\t\t\t\tFiscalía hace peritaje sobre cas...
# 14    \r\n\t\t\t\t\tDiputada Nora Lagunes, alerta qu...
# 15    \r\n\t\t\t\t\tConfirma Secretaría de Salud de ...
# 16    \r\n\t\t\t\t\t Detienen a presunto ladrón de l...
# ...

# %%
huatusco[['title','url']]
# Out:
#                                                 title  \
# 0   \r\n\t\t\t\t\tEn Huatusco, 350 ciclistas parti...
# 1   \r\n\t\t\t\t\tEsta es la primera especie que e...
# 2   \r\n\t\t\t\t\tEntregan proyectos productivos e...
# 3   \r\n\t\t\t\t\t Ciudadanas y ciudadanos nacidos...
# 4   \r\n\t\t\t\t\tLevantan a El Cocho Villafuer...
# 5   \r\n\t\t\t\t\t Asaltan y lesionan sujetos con ...
# 6   \r\n\t\t\t\t\tFuera Lety, el pueblo no te qui...
# 7   \r\n\t\t\t\t\t Comando armado levanta a ocho...
# 8   \r\n\t\t\t\t\tDisfrutan cordobeses de 1ra. Rod...
# 9   \r\n\t\t\t\t\tCae taxista de Huatusco con drog...
# 10  \r\n\t\t\t\t\tBajarán las multas de tránsito...
# 11  \r\n\t\t\t\t\t*Baristas fortalecen al café ver...
# 12  \r\n\t\t\t\t\tSe dispara deforestación en el P...
# 13  \r\n\t\t\t\t\tFiscalía hace peritaje sobre cas...
# 14  \r\n\t\t\t\t\tDiputada Nora Lagunes, alerta qu...
# 15  \r\n\t\t\t\t\tConfirma Secretaría de Salud de ...
# ...

# %%
#Numpy like

huatusco.iloc[:10]
# Out:
#                                                 body  \
# 0  \r\nCiclistas de diferentes municipios hiciero...
# 1  \r\nLa noticia de su extinción la dio a conoce...
# 2  \r\nAsí lo dio a conocer el Director del DIF m...
# 3  \r\nEsto a partir del sorteo que realizó el Co...
# 4  \r\nLos hechos ocurrieron minutos antes de las...
# 5  \r\n De acuerdo a información recabada, esto o...
# 6  \r\nAl arribo del Presidente de México al Parq...
# 7  \r\n \r\nLos hechos ocurrieron aproximadamente...
# 8  \r\nDicha actividad tiene como objetivos princ...
# 9  \r\nEsto sucedió en la colonia Reserva Territo...
#
#                                                title  \
# 0  \r\n\t\t\t\t\tEn Huatusco, 350 ciclistas parti...
# 1  \r\n\t\t\t\t\tEsta es la primera especie que e...
# 2  \r\n\t\t\t\t\tEntregan proyectos productivos e...
# 3  \r\n\t\t\t\t\t Ciudadanas y ciudadanos nacidos...
# 4  \r\n\t\t\t\t\tLevantan a El Cocho Villafuer...
# 5  \r\n\t\t\t\t\t Asaltan y lesionan sujetos con ...
# ...

# %%
huatusco.iloc[10]['title']
# Out:
# '\r\n\t\t\t\t\t\x93Bajarán las multas de tránsito\x94: Gobernador Yunes\t\t\t\r\n'

# %%
huatusco.iloc[:5,0]
# Out:
# 0    \r\nCiclistas de diferentes municipios hiciero...
# 1    \r\nLa noticia de su extinción la dio a conoce...
# 2    \r\nAsí lo dio a conocer el Director del DIF m...
# 3    \r\nEsto a partir del sorteo que realizó el Co...
# 4    \r\nLos hechos ocurrieron minutos antes de las...
# Name: body, dtype: object

# %%
huatusco.loc[:,'body':'title']
# Out:
#                                                  body  \
# 0   \r\nCiclistas de diferentes municipios hiciero...
# 1   \r\nLa noticia de su extinción la dio a conoce...
# 2   \r\nAsí lo dio a conocer el Director del DIF m...
# 3   \r\nEsto a partir del sorteo que realizó el Co...
# 4   \r\nLos hechos ocurrieron minutos antes de las...
# 5   \r\n De acuerdo a información recabada, esto o...
# 6   \r\nAl arribo del Presidente de México al Parq...
# 7   \r\n \r\nLos hechos ocurrieron aproximadamente...
# 8   \r\nDicha actividad tiene como objetivos princ...
# 9   \r\nEsto sucedió en la colonia Reserva Territo...
# 10  \r\n \r\nLas multas por infracciones de Tránsi...
# 11  \r\nLa integrante del Grupo Legislativo del PA...
# 12  \r\nPrestadores de servicios turísticos, y pob...
# 13  \r\nEn las diligencias realizados por los Peri...
# 14  \r\n La diputada panista alertó a las autorida...
# 15  \r\nLa presidenta municipal, Leticia López Lan...
# ...

# %% [markdown]
# # Data Wrangling

# %%
universal = pd.read_csv('./web_scrapper/eluniversal_2020_04_09_articles_2.csv')

# %%
#Obtener el host
from urllib.parse import urlparse

universal['host'] = universal['url'].apply(lambda url: urlparse(url).netloc)

universal
# Out:
#                                                  body  \
# 0   \r\nAllen Garfield, el veterano actor de carác...
# 1    Toggle navigation  SuscripcionesEl Universal ...
# 2   \r\n\r\nPuede ser que el coronavirus no distin...
# 3   \r\nMacKenzie Bezos ingresó de manera oficial ...
# 4   \r\n“Me dio mucha preocupación y miedo de que ...
# 5   \r\nEn esta Semana Santa, no hay actividad vac...
# 6   \r\nEl informe sobre la pérdida de empleo form...
# 7    0 % PULSO SOCIAL0 Hay canciones tan pegajosas...
# 8   \r\nEn tiempos de contingencia sanitaria y enc...
# 9   \r\n\r\nLa cantante y actriz Dulce María pasó ...
# 10  \r\n\r\nVámonos directo a las cifras y evitemo...
# 11  \r\nAntes de iniciar la temporada de 2019, el ...
# 12  \r\nLa modelo y corista Mollie Gould no ha par...
# 13  \r\nTlalnepantla, Méx.- Autoridades del Instit...
# 14  \r\n\r\n\r\n\r\n    googletag.cmd.push(functio...
# 15  \r\nMéxico llegó este miércoles 8 de abril a 3...
# ...

# %%
universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx         32
# www.viveusa.mx                  3
# www.eluniversalqueretaro.mx     3
# oaxaca.eluniversal.com.mx       2
# www.elgrafico.mx                2
# www.unionyucatan.mx             2
# sanluis.eluniversal.com.mx      1
# www.unionguanajuato.mx          1
# www.clubeluniversal.mx          1
# de10.com.mx                     1
# www.unionedomex.mx              1
# www.unioncdmx.mx                1
# www.unionpuebla.mx              1
# Name: host, dtype: int64

# %% [markdown]
# # Missing data

# %%
misign_titles_mask = universal['title'].isna()

# %%
misign_titles_mask
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34     True
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50     True
# Name: title, dtype: bool

# %%
missing_titles = (universal[misign_titles_mask]['url']
            .str.extract(r'(?P<missin_titles>[^/]+)$')
            .applymap(lambda title: title.split('-'))
            .applymap(lambda title_word_list:' '.join(title_word_list)))

# %%
universal.loc[misign_titles_mask, 'title'] = missing_titles.loc[:, 'missin_titles']

# %%
universal
# Out:
#                                                  body  \
# 0   \r\nAllen Garfield, el veterano actor de carác...
# 1    Toggle navigation  SuscripcionesEl Universal ...
# 2   \r\n\r\nPuede ser que el coronavirus no distin...
# 3   \r\nMacKenzie Bezos ingresó de manera oficial ...
# 4   \r\n“Me dio mucha preocupación y miedo de que ...
# 5   \r\nEn esta Semana Santa, no hay actividad vac...
# 6   \r\nEl informe sobre la pérdida de empleo form...
# 7    0 % PULSO SOCIAL0 Hay canciones tan pegajosas...
# 8   \r\nEn tiempos de contingencia sanitaria y enc...
# 9   \r\n\r\nLa cantante y actriz Dulce María pasó ...
# 10  \r\n\r\nVámonos directo a las cifras y evitemo...
# 11  \r\nAntes de iniciar la temporada de 2019, el ...
# 12  \r\nLa modelo y corista Mollie Gould no ha par...
# 13  \r\nTlalnepantla, Méx.- Autoridades del Instit...
# 14  \r\n\r\n\r\n\r\n    googletag.cmd.push(functio...
# 15  \r\nMéxico llegó este miércoles 8 de abril a 3...
# ...

# %% [markdown]
# # Additional Cleanup

# %%
#Añadir uid a las filas
import hashlib

uids = (universal
        .apply(lambda row: hashlib.md5(bytes(row['url'], 'utf-8')), axis = 1)
        .apply(lambda hash_object: hash_object.hexdigest())
        )
universal['uid'] = uids
universal.set_index('uid', inplace=True)
universal
# Out:
#                                                                                body  \
# uid
# 29eca5d5e99bb225afe0143f998f0dce  \r\nAllen Garfield, el veterano actor de carác...
# 3e542ff3beadc7730bbe798190f3cf39   Toggle navigation  SuscripcionesEl Universal ...
# 87396e894fc9ac71e9f15bd33664dd1e  \r\n\r\nPuede ser que el coronavirus no distin...
# 1ab5cc4de2cab97bd1db2811c0c7b12c  \r\nMacKenzie Bezos ingresó de manera oficial ...
# 4d20a15d23b6f435f4295568f3668dc8  \r\n“Me dio mucha preocupación y miedo de que ...
# 864409d0c2aa09f0c392049a53de3da9  \r\nEn esta Semana Santa, no hay actividad vac...
# 3ea0bf4c9e7e76aeb6a1f91872b75371  \r\nEl informe sobre la pérdida de empleo form...
# e84e6dce3b8e9aaa1ed9e5b639ab2f7d   0 % PULSO SOCIAL0 Hay canciones tan pegajosas...
# 51facaac131e18c40486cb2956f597b3  \r\nEn tiempos de contingencia sanitaria y enc...
# 0942f92e71f83bdc513ba32144699569  \r\n\r\nLa cantante y actriz Dulce María pasó ...
# ...

# %%
stripped_body = (universal
                 .apply(lambda row: row['body'], axis =1)
                 .apply(lambda body: list(body))
                 .apply(lambda letters: list(map(lambda letter: letter.replace('\n',''), letters)))
                 .apply(lambda letters: list(map(lambda letter: letter.replace('\r',''), letters)))
                 .apply(lambda letters: list(map(lambda letter: letter.replace('0',''), letters)))
                 .apply(lambda letters: list(map(lambda letter: letter.replace('%',''), letters)))
                 .apply(lambda letters:''.join(letters))
                )
stripped_body
# Out:
# uid
# 29eca5d5e99bb225afe0143f998f0dce    Allen Garfield, el veterano actor de carácter ...
# 3e542ff3beadc7730bbe798190f3cf39     Toggle navigation  SuscripcionesEl Universal ...
# 87396e894fc9ac71e9f15bd33664dd1e    Puede ser que el coronavirus no distinga color...
# 1ab5cc4de2cab97bd1db2811c0c7b12c    MacKenzie Bezos ingresó de manera oficial a la...
# 4d20a15d23b6f435f4295568f3668dc8    “Me dio mucha preocupación y miedo de que me c...
# 864409d0c2aa09f0c392049a53de3da9    En esta Semana Santa, no hay actividad vacacio...
# 3ea0bf4c9e7e76aeb6a1f91872b75371    El informe sobre la pérdida de empleo formal a...
# e84e6dce3b8e9aaa1ed9e5b639ab2f7d       PULSO SOCIAL Hay canciones tan pegajosas qu...
# 51facaac131e18c40486cb2956f597b3    En tiempos de contingencia sanitaria y encerra...
# 0942f92e71f83bdc513ba32144699569    La cantante y actriz Dulce María pasó momentos...
# 340ea48a62ff83de5fad3cc58fb01c63    Vámonos directo a las cifras y evitemos a toda...
# ...

# %% [markdown]
# # Data enrichment

# %%
# Tokenizar el titulo y el contenido
import nltk
from nltk.corpus import stopwords

stop_words = set(stopwords.words('spanish'))


def tokenize_column(df, columns_name):
    return (df
            .dropna()
            .apply(lambda row: nltk.word_tokenize(row[columns_name]), axis =1)
            .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
            .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
            .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
            .apply(lambda valid_word_list: len(valid_word_list)))

tokenizer = tokenize_column(universal , 'body')

# %%
universal['new'] = tokenizer

# %% [markdown]
# # Duplicate Values

# %%
#Eliminar duplicados

universal['title'].value_counts()
# Out:
# El país necesita que AMLO sea ambidiestro                                                           1
# Iglesia de Querétaro dará bendición en helicóptero contra el coronavirus                            1
# Valle Nacional, primer municipio oaxaqueño en usar drones para sanitizar sus calles por Covid-19    1
# Niña de 5 años es asesinada a golpes presuntamente por su padrastro en Nuevo León                   1
# La tormenta que traerá el Covid-19                                                                  1
# El devastador impacto del coronavirus entre los afroamericanos en EU                                1
# Genera indignación feminicidio de la niña Ana Paola durante cuarentena                              1
# 200 mdp van a San Luis Potosí para atender efectos por contingencia sanitaria                       1
# La Isla regresa, cuándo inicia en Azteca Siete                                                      1
# ...

# %%
universal.drop_duplicates(subset = ['title'], keep = 'first', inplace = True)

# %% [markdown]
# # Final table

# %%
universal
# Out:
#                                                  body  \
# 0   \r\nAllen Garfield, el veterano actor de carác...
# 1    Toggle navigation  SuscripcionesEl Universal ...
# 2   \r\n\r\nPuede ser que el coronavirus no distin...
# 4   \r\n“Me dio mucha preocupación y miedo de que ...
# 5   \r\nEn esta Semana Santa, no hay actividad vac...
# 6   \r\nEl informe sobre la pérdida de empleo form...
# 8   \r\nEn tiempos de contingencia sanitaria y enc...
# 9   \r\n\r\nLa cantante y actriz Dulce María pasó ...
# 10  \r\n\r\nVámonos directo a las cifras y evitemo...
# 11  \r\nAntes de iniciar la temporada de 2019, el ...
# 13  \r\nTlalnepantla, Méx.- Autoridades del Instit...
# 14  \r\n\r\n\r\n\r\n    googletag.cmd.push(functio...
# 15  \r\nMéxico llegó este miércoles 8 de abril a 3...
# 16  \r\nVino la epidemia y están cerrados los antr...
# 17  \r\nOaxaca de Juárez.- El 40% de las empresas ...
# 19  \r\n\r\nHace cinco días, dos grupos armados se...
# ...

# %% [markdown]
# # Descriptive analysis

# %%
clean_huatusco = pd.read_csv('./web_scrapper/clean_huatusco_2020_04_09_articles_2.csv')
clean_universal = pd.read_csv('./web_scrapper/clean_eluniversal_2020_04_09_articles_2.csv')

# %%
clean_huatusco.describe()
# Out:
#        n_token_title  n_token_body
# count      46.000000     46.000000
# mean        6.391304    124.521739
# std         2.113220     78.148787
# min         1.000000     29.000000
# 25%         5.000000     74.250000
# 50%         6.000000    103.500000
# 75%         8.000000    134.500000
# max        12.000000    427.000000

# %%
clean_universal.describe()
# Out:
#        n_token_title  n_token_body
# count      51.000000     51.000000
# mean        6.078431    244.450980
# std         2.225697    173.022231
# min         0.000000      9.000000
# 25%         5.000000    124.500000
# 50%         6.000000    207.000000
# 75%         7.000000    289.500000
# max        10.000000    872.000000

# %%
clean_universal.loc[clean_universal['n_token_title'] == 0]
# Out:
#                                  uid  \
# 47  987b7dac088e9a96c487de7739b13e20
#
#                                                  body  \
# 47  Read in English En febrero, cuando todo el mun...
#
#                          title  \
# 47  El hubiera de López-Gatell
#
#                                                   url newspaper_uid  \
# 47  https://www.eluniversal.com.mx/opinion/periodi...   eluniversal
#
#                       host  n_token_title  n_token_body
# 47  www.eluniversal.com.mx              0           283

# %%
# %matplotlib inline

# %%
clean_universal['n_token_title'].plot(style = 'k.')
clean_huatusco['n_token_title'].plot(style = 'r.')

# %%
clean_universal['n_token_body'].plot(style = 'k.')
clean_huatusco['n_token_body'].plot(style = 'r.')

# %%
all_newspaper = pd.concat([clean_huatusco, clean_universal])
grouped = all_newspaper.groupby('newspaper_uid')
grouped.hist()
# Out:
# newspaper_uid
# eluniversal    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# huatusco       [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_token_body'].agg(['min', 'mean', 'max'])
# Out:
#                min        mean  max
# newspaper_uid
# eluniversal      9  244.450980  872
# huatusco        29  124.521739  427

# %%
grouped.plot()
# Out:
# newspaper_uid
# eluniversal    AxesSubplot(0.125,0.125;0.775x0.755)
# huatusco       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
